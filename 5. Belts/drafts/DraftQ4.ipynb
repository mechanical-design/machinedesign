# %%
from math import pi, sin, cos, sqrt, pow, radians, degrees, asin, e

# %% [markdown]
# Q4
#
# A v belt drive with an included angle of 34° is to have a capacity of 15kW based on a coefficient of friction of 0.2 and a belt weight of 2.5N/m. Determine the required maximum belt tension at full load.
