# %% [markdown]
# Well defined

# %%
# Required
import matplotlib.pyplot as plt
import numpy as np
from math import sin, cos, tan, pi, atan, asin, degrees, radians

# %%
Power = 40000
n1=1500
module=4
pressureAngle=radians(20)

# %%
N1=350/2*2/7
print(f'N1={N1}')
N2=5*N1/2
print(f'N2={N2}')
# Out:
# N1=50.0
# N2=125.0

# %%
N3=200/2/4
print(f'N3={N3}')
N4=3*N3
print(f'N4={N4}')
# Out:
# N3=25.0
# N4=75.0

# %%
r1=module*N1/2
r2=module*N2/2
r3=module*N3/2
r4=module*N4/2
print(f'r1={r1} mm')
print(f'r2={r2} mm')
print(f'r3={r3} mm')
print(f'r4={r4} mm')
d1=2*r1
d2=2*r2
d3=2*r3
d4=2*r4
# Out:
# r1=100.0 mm
# r2=250.0 mm
# r3=50.0 mm
# r4=150.0 mm

# %%
n1=1500
n2=n1*N1/N2
print(f'n2={n2:.0f} rpm')
n3=n2
print(f'n3={n3:.0f}rpm')
n4=n3*N3/N4
print(f'n4={n4:.0f} rpm')
# Out:
# n2=600 rpm
# n3=600rpm
# n4=200 rpm

# %% [markdown]
# If the gear number 4 is reduced to 65, how does it affect gear 4 torque

# %%
print(n4)
Torque4=round(Power*60/(2*pi*n4),2)
print(f'Torque at Gear 4, T4={Torque4}Nm')
# Out:
# 200.0
# Torque at Gear 4, T4=1909.86Nm

# %%
new_N4=65
new_n4=n3*N3/new_N4
print(f'New n4={new_n4:.0f} rpm')
new_Torque4=round(Power*60/(2*pi*new_n4),2)
print(f'New Torque at Gear 4, T4={new_Torque4}Nm')
# Out:
# New n4=231 rpm
# New Torque at Gear 4, T4=1655.21Nm

# %% [markdown]
# What happens to the gear ratio and torque if the teeth on gear 2 are doubled

# %%
print(n4)
print(Torque4)
# Out:
# 200.0
# 1909.86

# %%
new_N2=250
new_n4=(N1/new_N2)*(N3/N4)*n1
print(f'New n4 with N2=250 is {new_n4:.0f} rpm')
# Out:
# New n4 with N2=250 is 100 rpm

# %%
new_Torque4=round(Power*60/(2*pi*new_n4),2)
print(f'New Torque at Gear 4, T4={new_Torque4}Nm')
# Out:
# New Torque at Gear 4, T4=3819.72Nm
